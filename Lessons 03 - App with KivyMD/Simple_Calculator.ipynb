# %%
from kivy.app import App
from kivy.core.window import Window
from kivy.uix.boxlayout import BoxLayout
from kivy.uix.button import Button
from kivy.uix.textinput import TextInput
from kivy.utils import platform
if platform == "android":
    from jnius import autoclass


# ## ### True ## False ### ## #
set_window_size = True
if platform == "android":
    PythonActivity = autoclass("org.kivy.android.PythonActivity")
    ActivityInfo = autoclass("android.content.pm.ActivityInfo")
    activity = PythonActivity.mActivity
    activity.setRequestedOrientation(ActivityInfo.SCREEN_ORIENTATION_USER)  # set orientation according to user's preference
elif set_window_size:
    Window.size = (540, 720)


class MainApp(App):
    def build(self):
        self.operators = ["/", "*", "+", "-"]
        self.last_was_operator = None
        self.last_button = None
        main_layout = BoxLayout(orientation="vertical")
        self.solution = TextInput(multiline=False, readonly=True, halign="right", font_size=55)
        main_layout.add_widget(self.solution)
        buttons = [
            ["7", "8", "9", "/"],
            ["4", "5", "6", "*"],
            ["1", "2", "3", "-"],
            [".", "0", "C", "+"],
        ]
        for row in buttons:
            h_layout = BoxLayout()
            for label in row:
                button = Button(text=label)
                button.bind(on_press=self.on_button_press)
                h_layout.add_widget(button)
            main_layout.add_widget(h_layout)

        h_layout = BoxLayout()
        equals_button = Button(text="=")
        equals_button.bind(on_press=self.on_solution)
        h_layout.add_widget(equals_button)

        edebug_button = Button(text="Debug", size_hint=(0.333333, 1))
        edebug_button.bind(on_press=self.print_debug)
        h_layout.add_widget(edebug_button)
        main_layout.add_widget(h_layout)

        return main_layout

    def on_button_press(self, instance):
        current = self.solution.text
        button_text = instance.text

        if button_text == "C":      # Clear the solution widget
            self.solution.text = ""
        else:
            if self.solution.text == "ERROR":
                current = ""
            if current == "" and button_text in self.operators:
                return  # First character cannot be an operator
            elif current and (self.last_was_operator and button_text in self.operators):
                new_text = current[:-1] + button_text
            else:
                new_text = current + button_text
            self.solution.text = new_text
        self.last_button = button_text
        self.last_was_operator = self.last_button in self.operators

    def on_solution(self, instance):
        text = self.solution.text
        if text:
            try:
                solution = str(eval(self.solution.text))
            except:
                solution = "ERROR"
            self.solution.text = solution

    def print_debug(self, instance):
        self.solution.text = f'x = {Window.size[0]}, y = {Window.size[1]}'


if __name__ == "__main__":
    app = MainApp()
    app.run()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-48813245fad4> in <cell line: 1>()
# ----> 1 from kivy.app import App
#       2 from kivy.uix.boxlayout import BoxLayout
#       3 from kivy.uix.button import Button
#       4 from kivy.uix.textinput import TextInput
#       5
#
# ModuleNotFoundError: No module named 'kivy'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !sudo apt update
# !sudo apt install -y git zip unzip openjdk-17-jdk python3-pip autoconf libtool pkg-config zlib1g-dev libncurses5-dev libncursesw5-dev libtinfo5 cmake libffi-dev libssl-dev
# !pip3 install --user --upgrade Cython==0.29.33 virtualenv
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [1,994 kB]
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,843 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,349 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,561 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [1,951 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,076 kB]
# Fetched 10.0 MB in 3s (3,343 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 40 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# autoconf is already the newest version (2.71-2).
# autoconf set to manually installed.
# pkg-config is already the newest version (0.29.2-1ubuntu3).
# zip is already the newest version (3.0-12build2).
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# git is already the newest version (1:2.34.1-1ubuntu1.10).
# libncurses5-dev is already the newest version (6.3-2ubuntu0.1).
# libssl-dev is already the newest version (3.0.2-0ubuntu1.15).
# unzip is already the newest version (6.0-26ubuntu3.2).
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu9.2).
# zlib1g-dev set to manually installed.
# The following additional packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java
#   libatk-wrapper-java-jni libfontenc1 libice-dev libsm-dev libxkbfile1
#   libxt-dev libxtst6 libxxf86dga1 openjdk-17-jdk-headless openjdk-17-jre
#   openjdk-17-jre-headless python3-setuptools python3-wheel x11-utils
# Suggested packages:
#   libice-doc libsm-doc libtool-doc gcj-jdk libxt-doc openjdk-17-demo
#   openjdk-17-source visualvm libnss-mdns fonts-ipafont-gothic
#   fonts-ipafont-mincho fonts-wqy-microhei | fonts-wqy-zenhei fonts-indic
#   python-setuptools-doc mesa-utils
# The following NEW packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java
#   libatk-wrapper-java-jni libffi-dev libfontenc1 libice-dev libncursesw5-dev
#   libsm-dev libtinfo5 libtool libxkbfile1 libxt-dev libxtst6 libxxf86dga1
#   openjdk-17-jdk openjdk-17-jdk-headless openjdk-17-jre
#   openjdk-17-jre-headless python3-pip python3-setuptools python3-wheel
#   x11-utils
# 0 upgraded, 23 newly installed, 0 to remove and 40 not upgraded.
# Need to get 128 MB of archives.
# After this operation, 299 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libice-dev amd64 2:1.0.10-1build2 [51.4 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libncursesw5-dev amd64 6.3-2ubuntu0.1 [790 B]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsm-dev amd64 2:1.2.3-1build2 [18.1 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libtinfo5 amd64 6.3-2ubuntu0.1 [100 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtool all 2.4.6-15build2 [164 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxt-dev amd64 1:1.2.1-1 [396 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 openjdk-17-jre-headless amd64 17.0.10+7-1~22.04.1 [48.2 MB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 openjdk-17-jre amd64 17.0.10+7-1~22.04.1 [203 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 openjdk-17-jdk-headless amd64 17.0.10+7-1~22.04.1 [71.1 MB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 openjdk-17-jdk amd64 17.0.10+7-1~22.04.1 [2,364 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-setuptools all 59.6.0-1.2ubuntu0.22.04.1 [339 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-wheel all 0.37.1-2ubuntu0.22.04.1 [32.0 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pip all 22.0.2+dfsg-1ubuntu0.4 [1,305 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libffi-dev amd64 3.4.2-4 [63.7 kB]
# Fetched 128 MB in 9s (13.5 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 23.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-dejavu-core.
# (Reading database ... 121749 files and directories currently installed.)
# Preparing to unpack .../00-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../01-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../02-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../03-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../04-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../05-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../06-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../07-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../08-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Selecting previously unselected package libice-dev:amd64.
# Preparing to unpack .../09-libice-dev_2%3a1.0.10-1build2_amd64.deb ...
# Unpacking libice-dev:amd64 (2:1.0.10-1build2) ...
# Selecting previously unselected package libncursesw5-dev:amd64.
# Preparing to unpack .../10-libncursesw5-dev_6.3-2ubuntu0.1_amd64.deb ...
# Unpacking libncursesw5-dev:amd64 (6.3-2ubuntu0.1) ...
# Selecting previously unselected package libsm-dev:amd64.
# Preparing to unpack .../11-libsm-dev_2%3a1.2.3-1build2_amd64.deb ...
# Unpacking libsm-dev:amd64 (2:1.2.3-1build2) ...
# Selecting previously unselected package libtinfo5:amd64.
# Preparing to unpack .../12-libtinfo5_6.3-2ubuntu0.1_amd64.deb ...
# Unpacking libtinfo5:amd64 (6.3-2ubuntu0.1) ...
# Selecting previously unselected package libtool.
# Preparing to unpack .../13-libtool_2.4.6-15build2_all.deb ...
# Unpacking libtool (2.4.6-15build2) ...
# Selecting previously unselected package libxt-dev:amd64.
# Preparing to unpack .../14-libxt-dev_1%3a1.2.1-1_amd64.deb ...
# Unpacking libxt-dev:amd64 (1:1.2.1-1) ...
# Selecting previously unselected package openjdk-17-jre-headless:amd64.
# Preparing to unpack .../15-openjdk-17-jre-headless_17.0.10+7-1~22.04.1_amd64.deb ...
# Unpacking openjdk-17-jre-headless:amd64 (17.0.10+7-1~22.04.1) ...
# Selecting previously unselected package openjdk-17-jre:amd64.
# Preparing to unpack .../16-openjdk-17-jre_17.0.10+7-1~22.04.1_amd64.deb ...
# Unpacking openjdk-17-jre:amd64 (17.0.10+7-1~22.04.1) ...
# Selecting previously unselected package openjdk-17-jdk-headless:amd64.
# Preparing to unpack .../17-openjdk-17-jdk-headless_17.0.10+7-1~22.04.1_amd64.deb ...
# Unpacking openjdk-17-jdk-headless:amd64 (17.0.10+7-1~22.04.1) ...
# Selecting previously unselected package openjdk-17-jdk:amd64.
# Preparing to unpack .../18-openjdk-17-jdk_17.0.10+7-1~22.04.1_amd64.deb ...
# Unpacking openjdk-17-jdk:amd64 (17.0.10+7-1~22.04.1) ...
# Selecting previously unselected package python3-setuptools.
# Preparing to unpack .../19-python3-setuptools_59.6.0-1.2ubuntu0.22.04.1_all.deb ...
# Unpacking python3-setuptools (59.6.0-1.2ubuntu0.22.04.1) ...
# Selecting previously unselected package python3-wheel.
# Preparing to unpack .../20-python3-wheel_0.37.1-2ubuntu0.22.04.1_all.deb ...
# Unpacking python3-wheel (0.37.1-2ubuntu0.22.04.1) ...
# Selecting previously unselected package python3-pip.
# Preparing to unpack .../21-python3-pip_22.0.2+dfsg-1ubuntu0.4_all.deb ...
# Unpacking python3-pip (22.0.2+dfsg-1ubuntu0.4) ...
# Selecting previously unselected package libffi-dev:amd64.
# Preparing to unpack .../22-libffi-dev_3.4.2-4_amd64.deb ...
# Unpacking libffi-dev:amd64 (3.4.2-4) ...
# Setting up python3-setuptools (59.6.0-1.2ubuntu0.22.04.1) ...
# Setting up libncursesw5-dev:amd64 (6.3-2ubuntu0.1) ...
# Setting up libice-dev:amd64 (2:1.0.10-1build2) ...
# Setting up libtool (2.4.6-15build2) ...
# Setting up libsm-dev:amd64 (2:1.2.3-1build2) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up libffi-dev:amd64 (3.4.2-4) ...
# Setting up python3-wheel (0.37.1-2ubuntu0.22.04.1) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up libxt-dev:amd64 (1:1.2.1-1) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up python3-pip (22.0.2+dfsg-1ubuntu0.4) ...
# Setting up openjdk-17-jre-headless:amd64 (17.0.10+7-1~22.04.1) ...
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/java to provide /usr/bin/java (java) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jpackage to provide /usr/bin/jpackage (jpackage) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/keytool to provide /usr/bin/keytool (keytool) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/rmiregistry to provide /usr/bin/rmiregistry (rmiregistry) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/lib/jexec to provide /usr/bin/jexec (jexec) in auto mode
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libtinfo5:amd64 (6.3-2ubuntu0.1) ...
# Setting up openjdk-17-jre:amd64 (17.0.10+7-1~22.04.1) ...
# Setting up openjdk-17-jdk-headless:amd64 (17.0.10+7-1~22.04.1) ...
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jar to provide /usr/bin/jar (jar) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jarsigner to provide /usr/bin/jarsigner (jarsigner) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/javac to provide /usr/bin/javac (javac) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/javadoc to provide /usr/bin/javadoc (javadoc) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/javap to provide /usr/bin/javap (javap) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jcmd to provide /usr/bin/jcmd (jcmd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jdb to provide /usr/bin/jdb (jdb) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jdeprscan to provide /usr/bin/jdeprscan (jdeprscan) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jdeps to provide /usr/bin/jdeps (jdeps) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jfr to provide /usr/bin/jfr (jfr) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jimage to provide /usr/bin/jimage (jimage) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jinfo to provide /usr/bin/jinfo (jinfo) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jlink to provide /usr/bin/jlink (jlink) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jmap to provide /usr/bin/jmap (jmap) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jmod to provide /usr/bin/jmod (jmod) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jps to provide /usr/bin/jps (jps) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jrunscript to provide /usr/bin/jrunscript (jrunscript) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jshell to provide /usr/bin/jshell (jshell) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jstack to provide /usr/bin/jstack (jstack) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jstat to provide /usr/bin/jstat (jstat) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jstatd to provide /usr/bin/jstatd (jstatd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/serialver to provide /usr/bin/serialver (serialver) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jhsdb to provide /usr/bin/jhsdb (jhsdb) in auto mode
# Setting up x11-utils (7.7+5build2) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up openjdk-17-jdk:amd64 (17.0.10+7-1~22.04.1) ...
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jconsole to provide /usr/bin/jconsole (jconsole) in auto mode
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Collecting Cython==0.29.33
#   Downloading Cython-0.29.33-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 10.2 MB/s eta 0:00:00
# Collecting virtualenv
#   Downloading virtualenv-20.25.1-py3-none-any.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 27.1 MB/s eta 0:00:00
# Collecting distlib<1,>=0.3.7 (from virtualenv)
#   Downloading distlib-0.3.8-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 30.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock<4,>=3.12.2 in /usr/local/lib/python3.10/dist-packages (from virtualenv) (3.13.1)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.10/dist-packages (from virtualenv) (4.2.0)
# Installing collected packages: distlib, virtualenv, Cython
#   WARNING: The script virtualenv is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts cygdb, cython and cythonize are installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed Cython-0.29.33 distlib-0.3.8 virtualenv-20.25.1

# %%
# git clone, for working on buildozer
# !git clone https://github.com/kivy/buildozer
# %cd buildozer
# !python setup.py build
# !pip install -e .
# %cd ..
# Out:
# Cloning into 'buildozer'...
# remote: Enumerating objects: 4779, done.
# remote: Counting objects: 100% (771/771), done.
# remote: Compressing objects: 100% (415/415), done.
# remote: Total 4779 (delta 509), reused 564 (delta 353), pack-reused 4008
# Receiving objects: 100% (4779/4779), 1.61 MiB | 5.01 MiB/s, done.
# Resolving deltas: 100% (3021/3021), done.
# /content/buildozer
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/buildozer
# copying buildozer/__init__.py -> build/lib/buildozer
# copying buildozer/exceptions.py -> build/lib/buildozer
# copying buildozer/target.py -> build/lib/buildozer
# copying buildozer/logger.py -> build/lib/buildozer
# copying buildozer/__main__.py -> build/lib/buildozer
# copying buildozer/jsonstore.py -> build/lib/buildozer
# copying buildozer/sitecustomize.py -> build/lib/buildozer
# copying buildozer/buildops.py -> build/lib/buildozer
# copying buildozer/specparser.py -> build/lib/buildozer
# creating build/lib/buildozer/targets
# copying buildozer/targets/__init__.py -> build/lib/buildozer/targets
# copying buildozer/targets/ios.py -> build/lib/buildozer/targets
# copying buildozer/targets/osx.py -> build/lib/buildozer/targets
# copying buildozer/targets/android.py -> build/lib/buildozer/targets
# creating build/lib/buildozer/libs
# copying buildozer/libs/__init__.py -> build/lib/buildozer/libs
# copying buildozer/libs/version.py -> build/lib/buildozer/libs
# copying buildozer/libs/_structures.py -> build/lib/buildozer/libs
# creating build/lib/buildozer/scripts
# copying buildozer/scripts/__init__.py -> build/lib/buildozer/scripts
# copying buildozer/scripts/client.py -> build/lib/buildozer/scripts
# copying buildozer/scripts/remote.py -> build/lib/buildozer/scripts
# running egg_info
# creating buildozer.egg-info
# writing buildozer.egg-info/PKG-INFO
# writing dependency_links to buildozer.egg-info/dependency_links.txt
# writing entry points to buildozer.egg-info/entry_points.txt
# writing requirements to buildozer.egg-info/requires.txt
# writing top-level names to buildozer.egg-info/top_level.txt
# writing manifest file 'buildozer.egg-info/SOURCES.txt'
# reading manifest file 'buildozer.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*COPYING'
# adding license file 'LICENSE'
# writing manifest file 'buildozer.egg-info/SOURCES.txt'
# copying buildozer/default.spec -> build/lib/buildozer
# Obtaining file:///content/buildozer
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pexpect in /usr/local/lib/python3.10/dist-packages (from buildozer==1.5.1.dev0) (4.9.0)
# Requirement already satisfied: cython<3.0 in /root/.local/lib/python3.10/site-packages (from buildozer==1.5.1.dev0) (0.29.33)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect->buildozer==1.5.1.dev0) (0.7.0)
# Installing collected packages: buildozer
#   Running setup.py develop for buildozer
# Successfully installed buildozer
# /content

# %%
# !buildozer init
# Out:
# Buildozer is running as root!
# This is not recommended, and may lead to problems later.
# Are you sure you want to continue [y/n]? y
# # Copy /content/buildozer/buildozer/default.spec to buildozer.spec
# File buildozer.spec created, ready to customize!

# %%
# !buildozer -v android debug
# Out:
# Buildozer is running as root!
# This is not recommended, and may lead to problems later.
# Are you sure you want to continue [y/n]? y
# # Ensure build layout
# # Check configuration tokens
# # Preparing build
# # Check requirements for android
# # Search for Git (git)
# #  -> found at /usr/bin/git
# # Search for Cython (cython)
# #  -> found at /usr/local/bin/cython
# # Search for Java compiler (javac)
# #  -> found at /usr/bin/javac
# # Search for Java keytool (keytool)
# #  -> found at /usr/bin/keytool
# # Install platform
# # Run 'git config --get remote.origin.url' ...
# # Cwd /content/.buildozer/android/platform/python-for-android
# https://github.com/kivy/python-for-android.git
# # Run 'git branch -vv' ...
# # Cwd /content/.buildozer/android/platform/python-for-android
# * master 957a3e5f [origin/master] Merge pull request #2959 from kivy/release-2024.01.21
# # Run '/usr/bin/python3 -m pip install -q --user appdirs colorama>=0.3.3 jinja2 sh>=1.10, <2.0; sys_platform!="win32" build toml packaging setuptools' ...
# # Cwd None
# # Apache ANT found at /root/.buildozer/android/platform/apache-ant-1.9.4
# # Android SDK found at /root/.buildozer/android/platform/android-sdk
# # Recommended android's NDK version by p4a is: 25b
# # Android NDK found at /root/.buildozer/android/platform/android-ndk-r25b
# # Run '/usr/bin/python3 -m pythonforandroid.toolchain aab -h --color=always --storage-dir=/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a --ndk-api=21 --ignore-setup-py --debug' ...
# # Cwd /content/.buildozer/android/platform/python-for-android
# [WARNING]: prerequisites.py is experimental and does not support all prerequisites yet.
# [WARNING]: Please report any issues to the python-for-android issue tracker.
# [WARNING]: prerequisites.py is experimental and does not support all prerequisites yet.
# [WARNING]: Please report any issues to the python-for-android issue tracker.
# usage: toolchain.py aab [-h] [--debug] [--color {always,never,auto}] [--sdk-dir SDK_DIR]
#                         [--ndk-dir NDK_DIR] [--android-api ANDROID_API]
#                         [--ndk-version NDK_VERSION] [--ndk-api NDK_API]
#                         [--symlink-bootstrap-files] [--storage-dir STORAGE_DIR] [--arch ARCH]
#                         [--dist-name DIST_NAME] [--requirements REQUIREMENTS]
#                         [--recipe-blacklist RECIPE_BLACKLIST]
#                         [--blacklist-requirements BLACKLIST_REQUIREMENTS] [--bootstrap BOOTSTRAP]
#                         [--hook HOOK] [--force-build] [--no-force-build] [--require-perfect-match]
#                         [--no-require-perfect-match] [--allow-replace-dist]
#                         [--no-allow-replace-dist] [--local-recipes LOCAL_RECIPES]
#                         [--activity-class-name ACTIVITY_CLASS_NAME]
#                         [--service-class-name SERVICE_CLASS_NAME]
#                         [--java-build-tool {auto,ant,gradle}] [--copy-libs] [--no-copy-libs]
#                         [--add-asset ASSETS] [--add-resource RESOURCES] [--private PRIVATE]
#                         [--use-setup-py] [--ignore-setup-py] [--release] [--with-debug-symbols]
#                         [--keystore KEYSTORE] [--signkey SIGNKEY] [--keystorepw KEYSTOREPW]
#                         [--signkeypw SIGNKEYPW]
#
# options:
#   -h, --help            show this help message and exit
#   --debug               Display debug output and all build info
#   --color {always,never,auto}
#                         Enable or disable color output (default enabled on tty)
#   --sdk-dir SDK_DIR, --sdk_dir SDK_DIR
#                         The filepath where the Android SDK is installed
#   --ndk-dir NDK_DIR, --ndk_dir NDK_DIR
#                         The filepath where the Android NDK is installed
#   --android-api ANDROID_API, --android_api ANDROID_API
#                         The Android API level to build against defaults to 33 if not specified.
#   --ndk-version NDK_VERSION, --ndk_version NDK_VERSION
#                         DEPRECATED: the NDK version is now found automatically or not at all.
#   --ndk-api NDK_API     The Android API level to compile against. This should be your *minimal
#                         supported* API, not normally the same as your --android-api. Defaults to
#                         min(ANDROID_API, 21) if not specified.
#   --symlink-bootstrap-files, --ssymlink_bootstrap_files
#                         If True, symlinks the bootstrap files creation. This is useful for
#                         development only, it could also cause weird problems.
#   --storage-dir STORAGE_DIR
#                         Primary storage directory for downloads and builds (default:
#                         /root/.local/share/python-for-android)
#   --arch ARCH           The archs to build for.
#   --dist-name DIST_NAME, --dist_name DIST_NAME
#                         The name of the distribution to use or create
#   --requirements REQUIREMENTS
#                         Dependencies of your app, should be recipe names or Python modules. NOT
#                         NECESSARY if you are using Python 3 with --use-setup-py
#   --recipe-blacklist RECIPE_BLACKLIST
#                         Blacklist an internal recipe from use. Allows disabling Python 3 core
#                         modules to save size
#   --blacklist-requirements BLACKLIST_REQUIREMENTS
#                         Blacklist an internal recipe from use. Allows disabling Python 3 core
#                         modules to save size
#   --bootstrap BOOTSTRAP
#                         The bootstrap to build with. Leave unset to choose automatically.
#   --hook HOOK           Filename to a module that contains python-for-android hooks
#   --local-recipes LOCAL_RECIPES, --local_recipes LOCAL_RECIPES
#                         Directory to look for local recipes
#   --activity-class-name ACTIVITY_CLASS_NAME
#                         The full java class name of the main activity
#   --service-class-name SERVICE_CLASS_NAME
#                         Full java package name of the PythonService class
#   --java-build-tool {auto,ant,gradle}
#                         The java build tool to use when packaging the APK, defaults to
#                         automatically selecting an appropriate tool.
#   --add-asset ASSETS    Put this in the assets folder in the apk.
#   --add-resource RESOURCES
#                         Put this in the res folder in the apk.
#   --private PRIVATE     the directory with the app source code files (containing your main.py
#                         entrypoint)
#   --use-setup-py        Process the setup.py of a project if present. (Experimental!
#   --ignore-setup-py     Don't run the setup.py of a project if present. This may be required if
#                         the setup.py is not designed to work inside p4a (e.g. by installing
#                         dependencies that won't work or aren't desired on Android
#   --release             Build your app as a non-debug release build. (Disables gdb debugging among
#                         other things)
#   --with-debug-symbols  Will keep debug symbols from `.so` files.
#   --keystore KEYSTORE   Keystore for JAR signing key, will use jarsigner default if not specified
#                         (release build only)
#   --signkey SIGNKEY     Key alias to sign PARSER_APK. with (release build only)
#   --keystorepw KEYSTOREPW
#                         Password for keystore
#   --signkeypw SIGNKEYPW
#                         Password for key alias
#
#   Whether to force compilation of a new distribution
#
#   --force-build
#   --no-force-build      (this is the default)
#   --require-perfect-match
#   --no-require-perfect-match
#                         (this is the default)
#   --allow-replace-dist  (this is the default)
#   --no-allow-replace-dist
#   --copy-libs
#   --no-copy-libs        (this is the default)
# # Check application requirements
# # Compile platform
# # Run '/usr/bin/python3 -m pythonforandroid.toolchain create --dist_name=myCalc --bootstrap=sdl2 --requirements=python3,kivy --arch=arm64-v8a --arch=armeabi-v7a --copy-libs --color=always --storage-dir=/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a --ndk-api=21 --ignore-setup-py --debug' ...
# # Cwd /content/.buildozer/android/platform/python-for-android
# [WARNING]: prerequisites.py is experimental and does not support all prerequisites yet.
# [WARNING]: Please report any issues to the python-for-android issue tracker.
# [WARNING]: prerequisites.py is experimental and does not support all prerequisites yet.
# [WARNING]: Please report any issues to the python-for-android issue tracker.
# [INFO]:    Will compile for the following archs: arm64-v8a, armeabi-v7a
# [INFO]:    Found Android API target in $ANDROIDAPI: 31
# [INFO]:    Available Android APIs are (31)
# [INFO]:    Requested API target 31 is available, continuing.
# [INFO]:    Found NDK dir in $ANDROIDNDK: /root/.buildozer/android/platform/android-ndk-r25b
# [INFO]:    Found NDK version 25b
# [INFO]:    Getting NDK API version (i.e. minimum supported API) from user argument
# [INFO]:    ccache is missing, the build will not be optimized in the future.
# [DEBUG]:   All possible dists: [<Distribution: name myCalc with recipes (hostpython3, libffi, openssl, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, six, pyjnius, android, kivy, chardet, urllib3, requests, idna, certifi)>]
# [DEBUG]:   Dist matching name and arch: [<Distribution: name myCalc with recipes (hostpython3, libffi, openssl, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, six, pyjnius, android, kivy, chardet, urllib3, requests, idna, certifi)>]
# [DEBUG]:   Dist matching ndk_api and recipe: [<Distribution: name myCalc with recipes (hostpython3, libffi, openssl, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, six, pyjnius, android, kivy, chardet, urllib3, requests, idna, certifi)>]
# [INFO]:    Of the existing distributions, the following meet the given requirements:
# [INFO]:    	myCalc: min API 21, includes recipes (hostpython3, libffi, openssl, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, six, pyjnius, android, kivy, chardet, urllib3, requests, idna, certifi), built for archs (arm64-v8a, armeabi-v7a)
# [INFO]:    myCalc has compatible recipes, using this one
# # Build the application #2
# # Copy application source from /content
# # Remove directory and subdirectory /content/.buildozer/android/app
# # Create directory /content/.buildozer/android/app
# # Copy /content/main.kv to /content/.buildozer/android/app/main.kv
# # Copy /content/main.py to /content/.buildozer/android/app/main.py
# # Create directory /content/.buildozer/android/app/buildozer
# # Copy /content/buildozer/LICENSE to /content/.buildozer/android/app/buildozer/LICENSE
# # Copy /content/buildozer/setup.py to /content/.buildozer/android/app/buildozer/setup.py
# # Copy /content/buildozer/Dockerfile to /content/.buildozer/android/app/buildozer/Dockerfile
# # Create directory /content/.buildozer/android/app/buildozer/buildozer.egg-info
# # Copy /content/buildozer/buildozer.egg-info/PKG-INFO to /content/.buildozer/android/app/buildozer/buildozer.egg-info/PKG-INFO
# # Create directory /content/.buildozer/android/app/buildozer/buildozer
# # Copy /content/buildozer/buildozer/__init__.py to /content/.buildozer/android/app/buildozer/buildozer/__init__.py
# # Copy /content/buildozer/buildozer/exceptions.py to /content/.buildozer/android/app/buildozer/buildozer/exceptions.py
# # Copy /content/buildozer/buildozer/target.py to /content/.buildozer/android/app/buildozer/buildozer/target.py
# # Copy /content/buildozer/buildozer/logger.py to /content/.buildozer/android/app/buildozer/buildozer/logger.py
# # Copy /content/buildozer/buildozer/__main__.py to /content/.buildozer/android/app/buildozer/buildozer/__main__.py
# # Copy /content/buildozer/buildozer/jsonstore.py to /content/.buildozer/android/app/buildozer/buildozer/jsonstore.py
# # Copy /content/buildozer/buildozer/sitecustomize.py to /content/.buildozer/android/app/buildozer/buildozer/sitecustomize.py
# # Copy /content/buildozer/buildozer/buildops.py to /content/.buildozer/android/app/buildozer/buildozer/buildops.py
# # Copy /content/buildozer/buildozer/specparser.py to /content/.buildozer/android/app/buildozer/buildozer/specparser.py
# # Create directory /content/.buildozer/android/app/buildozer/buildozer/libs
# # Copy /content/buildozer/buildozer/libs/__init__.py to /content/.buildozer/android/app/buildozer/buildozer/libs/__init__.py
# # Copy /content/buildozer/buildozer/libs/version.py to /content/.buildozer/android/app/buildozer/buildozer/libs/version.py
# # Copy /content/buildozer/buildozer/libs/_structures.py to /content/.buildozer/android/app/buildozer/buildozer/libs/_structures.py
# # Create directory /content/.buildozer/android/app/buildozer/buildozer/targets
# # Copy /content/buildozer/buildozer/targets/__init__.py to /content/.buildozer/android/app/buildozer/buildozer/targets/__init__.py
# # Copy /content/buildozer/buildozer/targets/ios.py to /content/.buildozer/android/app/buildozer/buildozer/targets/ios.py
# # Copy /content/buildozer/buildozer/targets/osx.py to /content/.buildozer/android/app/buildozer/buildozer/targets/osx.py
# # Copy /content/buildozer/buildozer/targets/android.py to /content/.buildozer/android/app/buildozer/buildozer/targets/android.py
# # Create directory /content/.buildozer/android/app/buildozer/buildozer/tools/packer
# # Copy /content/buildozer/buildozer/tools/packer/CHANGELOG to /content/.buildozer/android/app/buildozer/buildozer/tools/packer/CHANGELOG
# # Copy /content/buildozer/buildozer/tools/packer/launch to /content/.buildozer/android/app/buildozer/buildozer/tools/packer/launch
# # Copy /content/buildozer/buildozer/tools/packer/Makefile to /content/.buildozer/android/app/buildozer/buildozer/tools/packer/Makefile
# # Create directory /content/.buildozer/android/app/buildozer/buildozer/tools/packer/http
# # Copy /content/buildozer/buildozer/tools/packer/http/wallpaper.png to /content/.buildozer/android/app/buildozer/buildozer/tools/packer/http/wallpaper.png
# # Copy /content/buildozer/buildozer/tools/packer/http/kivy-icon-96.png to /content/.buildozer/android/app/buildozer/buildozer/tools/packer/http/kivy-icon-96.png
# # Create directory /content/.buildozer/android/app/buildozer/buildozer/scripts
# # Copy /content/buildozer/buildozer/scripts/__init__.py to /content/.buildozer/android/app/buildozer/buildozer/scripts/__init__.py
# # Copy /content/buildozer/buildozer/scripts/client.py to /content/.buildozer/android/app/buildozer/buildozer/scripts/client.py
# # Copy /content/buildozer/buildozer/scripts/remote.py to /content/.buildozer/android/app/buildozer/buildozer/scripts/remote.py
# # Create directory /content/.buildozer/android/app/buildozer/docs
# # Copy /content/buildozer/docs/Makefile to /content/.buildozer/android/app/buildozer/docs/Makefile
# # Create directory /content/.buildozer/android/app/buildozer/docs/source
# # Copy /content/buildozer/docs/source/conf.py to /content/.buildozer/android/app/buildozer/docs/source/conf.py
# # Create directory /content/.buildozer/android/app/buildozer/build/lib/buildozer
# # Copy /content/buildozer/build/lib/buildozer/__init__.py to /content/.buildozer/android/app/buildozer/build/lib/buildozer/__init__.py
# # Copy /content/buildozer/build/lib/buildozer/exceptions.py to /content/.buildozer/android/app/buildozer/build/lib/buildozer/exceptions.py
# # Copy /content/buildozer/build/lib/buildozer/target.py to /content/.buildozer/android/app/buildozer/build/lib/buildozer/target.py
# # Copy /content/buildozer/build/lib/buildozer/logger.py to /content/.buildozer/android/app/buildozer/build/lib/buildozer/logger.py
# # Copy /content/buildozer/build/lib/buildozer/__main__.py to /content/.buildozer/android/app/buildozer/build/lib/buildozer/__main__.py
# # Copy /content/buildozer/build/lib/buildozer/jsonstore.py to /content/.buildozer/android/app/buildozer/build/lib/buildozer/jsonstore.py
# # Copy /content/buildozer/build/lib/buildozer/sitecustomize.py to /content/.buildozer/android/app/buildozer/build/lib/buildozer/sitecustomize.py
# # Copy /content/buildozer/build/lib/buildozer/buildops.py to /content/.buildozer/android/app/buildozer/build/lib/buildozer/buildops.py
# # Copy /content/buildozer/build/lib/buildozer/specparser.py to /content/.buildozer/android/app/buildozer/build/lib/buildozer/specparser.py
# # Create directory /content/.buildozer/android/app/buildozer/build/lib/buildozer/libs
# # Copy /content/buildozer/build/lib/buildozer/libs/__init__.py to /content/.buildozer/android/app/buildozer/build/lib/buildozer/libs/__init__.py
# # Copy /content/buildozer/build/lib/buildozer/libs/version.py to /content/.buildozer/android/app/buildozer/build/lib/buildozer/libs/version.py
# # Copy /content/buildozer/build/lib/buildozer/libs/_structures.py to /content/.buildozer/android/app/buildozer/build/lib/buildozer/libs/_structures.py
# # Create directory /content/.buildozer/android/app/buildozer/build/lib/buildozer/targets
# # Copy /content/buildozer/build/lib/buildozer/targets/__init__.py to /content/.buildozer/android/app/buildozer/build/lib/buildozer/targets/__init__.py
# # Copy /content/buildozer/build/lib/buildozer/targets/ios.py to /content/.buildozer/android/app/buildozer/build/lib/buildozer/targets/ios.py
# # Copy /content/buildozer/build/lib/buildozer/targets/osx.py to /content/.buildozer/android/app/buildozer/build/lib/buildozer/targets/osx.py
# # Copy /content/buildozer/build/lib/buildozer/targets/android.py to /content/.buildozer/android/app/buildozer/build/lib/buildozer/targets/android.py
# # Create directory /content/.buildozer/android/app/buildozer/build/lib/buildozer/scripts
# # Copy /content/buildozer/build/lib/buildozer/scripts/__init__.py to /content/.buildozer/android/app/buildozer/build/lib/buildozer/scripts/__init__.py
# # Copy /content/buildozer/build/lib/buildozer/scripts/client.py to /content/.buildozer/android/app/buildozer/build/lib/buildozer/scripts/client.py
# # Copy /content/buildozer/build/lib/buildozer/scripts/remote.py to /content/.buildozer/android/app/buildozer/build/lib/buildozer/scripts/remote.py
# # Create directory /content/.buildozer/android/app/buildozer/tests
# # Copy /content/buildozer/tests/__init__.py to /content/.buildozer/android/app/buildozer/tests/__init__.py
# # Copy /content/buildozer/tests/test_buildozer.py to /content/.buildozer/android/app/buildozer/tests/test_buildozer.py
# # Copy /content/buildozer/tests/test_buildops.py to /content/.buildozer/android/app/buildozer/tests/test_buildops.py
# # Copy /content/buildozer/tests/test_logger.py to /content/.buildozer/android/app/buildozer/tests/test_logger.py
# # Copy /content/buildozer/tests/test_specparser.py to /content/.buildozer/android/app/buildozer/tests/test_specparser.py
# # Create directory /content/.buildozer/android/app/buildozer/tests/targets
# # Copy /content/buildozer/tests/targets/test_android.py to /content/.buildozer/android/app/buildozer/tests/targets/test_android.py
# # Copy /content/buildozer/tests/targets/test_ios.py to /content/.buildozer/android/app/buildozer/tests/targets/test_ios.py
# # Copy /content/buildozer/tests/targets/utils.py to /content/.buildozer/android/app/buildozer/tests/targets/utils.py
# # Create directory /content/.buildozer/android/app/buildozer/tests/scripts
# # Copy /content/buildozer/tests/scripts/test_client.py to /content/.buildozer/android/app/buildozer/tests/scripts/test_client.py
# # Copy /content/buildozer/tests/scripts/__init__.py to /content/.buildozer/android/app/buildozer/tests/scripts/__init__.py
# # copy /content/.buildozer/applibs to /content/.buildozer/android/app/_applibs
# # Copy /content/buildozer/buildozer/sitecustomize.py to /content/.buildozer/android/app/sitecustomize.py
# # Package the application
# # project.properties updated
# # Run '/usr/bin/python3 -m pythonforandroid.toolchain apk --bootstrap sdl2 --dist_name myCalc --name My Simple Calculator --version 1 --package org.test.mycalc --minsdk 21 --ndk-api 21 --private /content/.buildozer/android/app --android-entrypoint org.kivy.android.PythonActivity --android-apptheme @android:style/Theme.NoTitleBar --orientation portrait --window --enable-androidx --copy-libs --arch arm64-v8a --arch armeabi-v7a --color=always --storage-dir=/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a --ndk-api=21 --ignore-setup-py --debug' ...
# # Cwd /content/.buildozer/android/platform/python-for-android
# [WARNING]: prerequisites.py is experimental and does not support all prerequisites yet.
# [WARNING]: Please report any issues to the python-for-android issue tracker.
# [WARNING]: prerequisites.py is experimental and does not support all prerequisites yet.
# [WARNING]: Please report any issues to the python-for-android issue tracker.
# [INFO]:    Will compile for the following archs: arm64-v8a, armeabi-v7a
# [INFO]:    Found Android API target in $ANDROIDAPI: 31
# [INFO]:    Available Android APIs are (31)
# [INFO]:    Requested API target 31 is available, continuing.
# [INFO]:    Found NDK dir in $ANDROIDNDK: /root/.buildozer/android/platform/android-ndk-r25b
# [INFO]:    Found NDK version 25b
# [INFO]:    Getting NDK API version (i.e. minimum supported API) from user argument
# [INFO]:    ccache is missing, the build will not be optimized in the future.
# [DEBUG]:   All possible dists: [<Distribution: name myCalc with recipes (hostpython3, libffi, openssl, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, six, pyjnius, android, kivy, chardet, urllib3, requests, idna, certifi)>]
# [DEBUG]:   Dist matching name and arch: [<Distribution: name myCalc with recipes (hostpython3, libffi, openssl, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, six, pyjnius, android, kivy, chardet, urllib3, requests, idna, certifi)>]
# [DEBUG]:   Dist matching ndk_api and recipe: [<Distribution: name myCalc with recipes (hostpython3, libffi, openssl, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, six, pyjnius, android, kivy, chardet, urllib3, requests, idna, certifi)>]
# [INFO]:    Of the existing distributions, the following meet the given requirements:
# [INFO]:    	myCalc: min API 21, includes recipes (hostpython3, libffi, openssl, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, six, pyjnius, android, kivy, chardet, urllib3, requests, idna, certifi), built for archs (arm64-v8a, armeabi-v7a)
# [INFO]:    myCalc has compatible recipes, using this one
# [DEBUG]:   All possible dists: [<Distribution: name myCalc with recipes (hostpython3, libffi, openssl, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, six, pyjnius, android, kivy, chardet, urllib3, requests, idna, certifi)>]
# [DEBUG]:   Dist matching name and arch: [<Distribution: name myCalc with recipes (hostpython3, libffi, openssl, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, six, pyjnius, android, kivy, chardet, urllib3, requests, idna, certifi)>]
# [DEBUG]:   Dist matching ndk_api and recipe: [<Distribution: name myCalc with recipes (hostpython3, libffi, openssl, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, six, pyjnius, android, kivy, chardet, urllib3, requests, idna, certifi)>]
# [INFO]:    Of the existing distributions, the following meet the given requirements:
# [INFO]:    	myCalc: min API 21, includes recipes (hostpython3, libffi, openssl, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, six, pyjnius, android, kivy, chardet, urllib3, requests, idna, certifi), built for archs (arm64-v8a, armeabi-v7a)
# [INFO]:    myCalc has compatible recipes, using this one
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/bootstrap_builds/sdl2
# [INFO]:    <- directory context /content/.buildozer/android/platform/python-for-android
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/dists/myCalc
# [DEBUG]:   Remove directory and subdirectory src/main/assets
# [DEBUG]:   Create directory src/main/assets
# Compiling '/content/.buildozer/android/app/sitecustomize.py'...
# Compiling '/content/.buildozer/android/app/main.py'...
# Compiling '/content/.buildozer/android/app/buildozer/setup.py'...
# Compiling '/content/.buildozer/android/app/buildozer/buildozer/__init__.py'...
# Compiling '/content/.buildozer/android/app/buildozer/buildozer/exceptions.py'...
# Compiling '/content/.buildozer/android/app/buildozer/buildozer/target.py'...
# Compiling '/content/.buildozer/android/app/buildozer/buildozer/logger.py'...
# Compiling '/content/.buildozer/android/app/buildozer/buildozer/__main__.py'...
# Compiling '/content/.buildozer/android/app/buildozer/buildozer/jsonstore.py'...
# Compiling '/content/.buildozer/android/app/buildozer/buildozer/sitecustomize.py'...
# Compiling '/content/.buildozer/android/app/buildozer/buildozer/buildops.py'...
# Compiling '/content/.buildozer/android/app/buildozer/buildozer/specparser.py'...
# Compiling '/content/.buildozer/android/app/buildozer/buildozer/libs/__init__.py'...
# Compiling '/content/.buildozer/android/app/buildozer/buildozer/libs/version.py'...
# Compiling '/content/.buildozer/android/app/buildozer/buildozer/libs/_structures.py'...
# Compiling '/content/.buildozer/android/app/buildozer/buildozer/targets/__init__.py'...
# Compiling '/content/.buildozer/android/app/buildozer/buildozer/targets/ios.py'...
# Compiling '/content/.buildozer/android/app/buildozer/buildozer/targets/osx.py'...
# Compiling '/content/.buildozer/android/app/buildozer/buildozer/targets/android.py'...
# Compiling '/content/.buildozer/android/app/buildozer/buildozer/scripts/__init__.py'...
# Compiling '/content/.buildozer/android/app/buildozer/buildozer/scripts/client.py'...
# Compiling '/content/.buildozer/android/app/buildozer/buildozer/scripts/remote.py'...
# Compiling '/content/.buildozer/android/app/buildozer/docs/source/conf.py'...
# Compiling '/content/.buildozer/android/app/buildozer/build/lib/buildozer/__init__.py'...
# Compiling '/content/.buildozer/android/app/buildozer/build/lib/buildozer/exceptions.py'...
# Compiling '/content/.buildozer/android/app/buildozer/build/lib/buildozer/target.py'...
# Compiling '/content/.buildozer/android/app/buildozer/build/lib/buildozer/logger.py'...
# Compiling '/content/.buildozer/android/app/buildozer/build/lib/buildozer/__main__.py'...
# Compiling '/content/.buildozer/android/app/buildozer/build/lib/buildozer/jsonstore.py'...
# Compiling '/content/.buildozer/android/app/buildozer/build/lib/buildozer/sitecustomize.py'...
# Compiling '/content/.buildozer/android/app/buildozer/build/lib/buildozer/buildops.py'...
# Compiling '/content/.buildozer/android/app/buildozer/build/lib/buildozer/specparser.py'...
# Compiling '/content/.buildozer/android/app/buildozer/build/lib/buildozer/libs/__init__.py'...
# Compiling '/content/.buildozer/android/app/buildozer/build/lib/buildozer/libs/version.py'...
# Compiling '/content/.buildozer/android/app/buildozer/build/lib/buildozer/libs/_structures.py'...
# Compiling '/content/.buildozer/android/app/buildozer/build/lib/buildozer/targets/__init__.py'...
# Compiling '/content/.buildozer/android/app/buildozer/build/lib/buildozer/targets/ios.py'...
# Compiling '/content/.buildozer/android/app/buildozer/build/lib/buildozer/targets/osx.py'...
# Compiling '/content/.buildozer/android/app/buildozer/build/lib/buildozer/targets/android.py'...
# Compiling '/content/.buildozer/android/app/buildozer/build/lib/buildozer/scripts/__init__.py'...
# Compiling '/content/.buildozer/android/app/buildozer/build/lib/buildozer/scripts/client.py'...
# Compiling '/content/.buildozer/android/app/buildozer/build/lib/buildozer/scripts/remote.py'...
# Compiling '/content/.buildozer/android/app/buildozer/tests/__init__.py'...
# Compiling '/content/.buildozer/android/app/buildozer/tests/test_buildozer.py'...
# Compiling '/content/.buildozer/android/app/buildozer/tests/test_buildops.py'...
# Compiling '/content/.buildozer/android/app/buildozer/tests/test_logger.py'...
# Compiling '/content/.buildozer/android/app/buildozer/tests/test_specparser.py'...
# Compiling '/content/.buildozer/android/app/buildozer/tests/targets/test_android.py'...
# Compiling '/content/.buildozer/android/app/buildozer/tests/targets/test_ios.py'...
# Compiling '/content/.buildozer/android/app/buildozer/tests/targets/utils.py'...
# Compiling '/content/.buildozer/android/app/buildozer/tests/scripts/test_client.py'...
# Compiling '/content/.buildozer/android/app/buildozer/tests/scripts/__init__.py'...
# [DEBUG]:   Remove directory and subdirectory /tmp/p4a-extra-env-p0mlz_na
# [INFO]:    Detected highest available build tools version to be 35.0.0-rc1
# [DEBUG]:   -> running gradlew clean assembleDebug
# [DEBUG]:   	Downloading https://services.gradle.org/distributions/gradle-8.0.2-all.zip
# [DEBUG]:   	.................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................... ...
# [DEBUG]:   	Unzipping /root/.gradle/wrapper/dists/gradle-8.0.2-all/14bt34ptcsg1ikmfn78tdh1keu/gradle-8.0.2-all.zip to /root/.gradle/wrapper/dists/gradle-8.0.2-all/14bt34ptcsg1ikmfn78tdh1keu
# [DEBUG]:   	Set executable permissions for: /root/.gradle/wrapper/dists/gradle-8.0.2-all/14bt34ptcsg1ikmfn78tdh1keu/gradle-8.0.2/bin/gradle
# [DEBUG]:
# [DEBUG]:   	Welcome to Gradle 8.0.2!
# [DEBUG]:
# [DEBUG]:   	Here are the highlights of this release:
# [DEBUG]:   	 - Improvements to the Kotlin DSL
# [DEBUG]:   	 - Fine-grained parallelism from the first build with configuration cache
# [DEBUG]:   	 - Configurable Gradle user home cache cleanup
# [DEBUG]:
# [DEBUG]:   	For more details see https://docs.gradle.org/8.0.2/release-notes.html
# [DEBUG]:
# [DEBUG]:   	Starting a Gradle Daemon (subsequent builds will be faster)
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:   	> Starting Daemon> IDLE<-------------> 0% INITIALIZING s]<-------------> 0% INITIALIZING s]<-------------> 0% INITIALIZING s]<-------------> 0% INITIALIZING s]<-------------> 0% INITIALIZING s]<-------------> 0% INITIALIZING s]<-------------> 0% INITIALIZING s]<-------------> 0% INITIALIZING s]<-------------> 0% INITIALIZING s]<-------------> 0% INITIALIZING s]> Evaluating settings<-------------> 0% INITIALIZING [1s]<-------------> 0% INITIALIZING [2s]<-------------> 0% CONFIGURING [2s]> Loading projects> root project<-------------> 0% CONFIGURING [3s]> root project > Compiling build file 'build.gradle'<-------------> 0% CONFIGURING [4s]> root project<-------------> 0% CONFIGURING [5s]<-------------> 0% CONFIGURING [6s]> root project > Resolve dependencies of :classpath> root project > Resolve dependencies of :classpath > gradle-8.1.1.pom<-------------> 0% CONFIGURING [7s]<-------------> 0% CONFIGURING [8s]> root project > Resolve dependencies of :classpath> root project > Resolve dependencies of :classpath > gradle-8.1.1.module> root project > Resolve dependencies of :classpath> root project > Resolve dependencies of :classpath > gradle-settings-api-8.1.1
# [DEBUG]:   	> root project > Resolve dependencies of :classpath > sdklib-31.1.1.pom> root project > Resolve dependencies of :classpath > android-test-plugin-host-<-------------> 0% CONFIGURING [9s]> root project > Resolve dependencies of :classpath > android-test-plugin-host-> root project > Resolve dependencies of :classpath > android-test-plugin-resul> root project > Resolve dependencies of :classpath > kotlin-stdlib-jdk8-1.8.20> root project > Resolve dependencies of :classpath > transform-api-2.0.0-depre> IDLE> root project > Resolve dependencies of :classpath > httpmime-4.5.6.pom<-------------> 0% CONFIGURING [10s]> root project > Resolve dependencies of :classpath > commons-io-2.4.pom> root project > Resolve dependencies of :classpath > httpcomponents-client-4.5> root project > Resolve dependencies of :classpath > commons-parent-25.pom> root project > Resolve dependencies of :classpath > httpcomponents-parent-10.> root project > Resolve dependencies of :classpath > apache-9.pom> IDLE> root project > Resolve dependencies of :classpath > asm-9.2.pom> root project > Resolve dependencies of :classpath > apache-18.pom> root project > Resolve dependencies of :classpath > ow2-1.5.pom<-------------> 0% CONFIGURING [11s]> IDLE> root project > Resolve dependencies of :classpath > asm-analysis-9.2.pom> root project > Resolve dependencies of :classpath > asm-util-9.2.pom> root project > Resolve dependencies of :classpath > bcpkix-jdk15on-1.67.pom> root project > Resolve dependencies of :classpath > asm-util-9.2.pom > 2 KiB/> root project > Resolve dependencies of :classpath > jopt-simple-4.9.pom> root project > Resolve dependencies of :classpath > jaxb-runtime-2.3.2.pom> root project > Resolve dependencies of :classpath > oss-parent-7.pom> root project > Resolve dependencies of :classpath > jaxb-runtime-parent-2.3.2> IDLE> root project > Resolve dependencies of :classpath > jaxb-parent-2.3.2.pom<-------------> 0% CONFIGURING [12s]> root project > Resolve dependencies of :classpath > bundletool-1.14.0.pom> IDLE> root project > Resolve dependencies of :classpath > jaxb-bom-ext-2.3.2.pom> root project > Resolve dependencies of :classpath > jetifier-core-1.0.0-beta1> root project > Resolve dependencies of :classpath > jaxb-bom-2.3.2.pom> root project > Resolve dependencies of :classpath > project-1.0.5.pom> root project > Resolve dependencies of :classpath > jetifier-processor-1.0.0-> IDLE<-------------> 0% CONFIGURING [13s]> root project > Resolve dependencies of :classpath > javapoet-1.10.0.pom> IDLE> root project > Resolve dependencies of :classpath > protobuf-java-3.19.3.pom> root project > Resolve dependencies of :classpath > protobuf-parent-3.19.3.po> root project > Resolve dependencies of :classpath > protobuf-java-util-3.19.3> root project > Resolve dependencies of :classpath > protobuf-bom-3.19.3.pom<-------------> 0% CONFIGURING [14s]> root project > Resolve dependencies of :classpath > gson-2.8.6.pom> root project > Resolve dependencies of :classpath > repository-31.1.1.pom> root project > Resolve dependencies of :classpath > gson-parent-2.8.6.pom> root project > Resolve dependencies of :classpath > grpc-core-1.45.1.pom> root project > Resolve dependencies of :classpath > grpc-netty-1.45.1.pom> root project > Resolve dependencies of :classpath > grpc-protobuf-1.45.1.pom> root project > Resolve dependencies of :classpath > grpc-stub-1.45.1.pom> root project > Resolve dependencies of :classpath > tink-1.7.0.pom<-------------> 0% CONFIGURING [15s]> root project > Resolve dependencies of :classpath > flatbuffers-java-1.12.0.p> root project > Resolve dependencies of :classpath > tensorflow-lite-metadata-> IDLE> root project > Resolve dependencies of :classpath > builder-8.1.1.module> root project > Resolve dependencies of :classpath > builder-model-8.1.1.pom> root project > Resolve dependencies of :classpath > gradle-api-8.1.1.pom> root project > Resolve dependencies of :classpath > gradle-api-8.1.1.module> root project > Resolve  ...
# [DEBUG]:   	> Task :processDebugMainManifest
# [DEBUG]:   	/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/dists/myCalc/src/main/AndroidManifest.xml:53:18-50 Warning:
# [DEBUG]:   	        android:extractNativeLibs should not be specified in this source AndroidManifest.xml file. See https://d.android.com/guide/topics/manifest/application-element#extractNativeLibs for more information.
# [DEBUG]:   	The AGP Upgrade Assistant can remove the attribute from the AndroidManifest.xml file and update the build file accordingly. See https://d.android.com/studio/build/agp-upgrade-assistant for more information.
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:   	<====---------> 36% EXECUTING  16s]> IDLE> :processDebugManifest<====---------> 36% EXECUTING  17s]<=====--------> 41% EXECUTING  17s]> :processDebugManifestForPackage<======-------> 46% EXECUTING  17s]> :processDebugResources > Resolve dependencies of :detachedConfiguration2 > aa> :processDebugResources > Resolve files of :detachedConfiguration2 > aapt2-8.1<======-------> 46% EXECUTING  18s]<======-------> 46% EXECUTING  19s]> :processDebugResources > Resolve files of :detachedConfiguration2> :processDebugResources > Resolve files of :detachedConfiguration2 > Aapt2Extr> :processDebugResources<======-------> 51% EXECUTING  19s]> :compressDebugAssets<=======------> 56% EXECUTING  19s]> :mergeDebugJavaResource<=======------> 60% EXECUTING  20s]> :desugarDebugFileDependencies<========-----> 63% EXECUTING  20s]> IDLE<========-----> 63% EXECUTING  21s]<========-----> 65% EXECUTING  21s]> :compileDebugJavaWithJavac<========-----> 65% EXECUTING  22s]<========-----> 65% EXECUTING  23s]<========-----> 65% EXECUTING  24s]<========-----> 65% EXECUTING  25s]<========-----> 65% EXECUTING  26s]
# [DEBUG]:   	> Task :compileDebugJavaWithJavac
# [DEBUG]:   	Note: Some input files use or override a deprecated API.
# [DEBUG]:   	Note: Recompile with -Xlint:deprecation for details.
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:   	<========-----> 65% EXECUTING  26s]> :compileDebugJavaWithJavac> IDLE<========-----> 65% EXECUTING  27s]<========-----> 68% EXECUTING  27s]> :mergeExtDexDebug> :mergeLibDexDebug<=========----> 73% EXECUTING  27s]> :dexBuilderDebug> IDLE<=========----> 73% EXECUTING  28s]<=========----> 73% EXECUTING  29s]<=========----> 73% EXECUTING  30s]<=========----> 73% EXECUTING  31s]<=========----> 73% EXECUTING  32s]<=========----> 73% EXECUTING  33s]<=========----> 73% EXECUTING  34s]<=========----> 75% EXECUTING  34s]> :mergeProjectDexDebug> :mergeDebugJniLibFolders<==========---> 78% EXECUTING  35s]> IDLE<==========---> 80% EXECUTING  35s]> :mergeDebugNativeLibs> :validateSigningDebug<==========---> 82% EXECUTING  35s]> IDLE<==========---> 82% EXECUTING  36s]<===========--> 85% EXECUTING  36s]> :stripDebugDebugSymbols> :writeDebugAppMetadata<===========--> 90% EXECUTING  37s]> IDLE<============-> 92% EXECUTING  37s]> :packageDebug<============-> 92% EXECUTING  38s]<============-> 92% EXECUTING  39s]<============-> 92% EXECUTING  40s]<============-> 92% EXECUTING  41s]
# [DEBUG]:   	Deprecated Gradle features were used in this build, making it incompatible with Gradle 9.0.
# [DEBUG]:
# [DEBUG]:   	You can use '--warning-mode all' to show the individual deprecation warnings and determine if they come from your own scripts or plugins.
# [DEBUG]:
# [DEBUG]:   	See https://docs.gradle.org/8.0.2/userguide/command_line_interface.html#sec:command_line_warnings
# [DEBUG]:
# [DEBUG]:   	BUILD SUCCESSFUL in 1m 54s
# [DEBUG]:   	33 actionable tasks: 32 executed, 1 up-to-date
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:   	<-------------> 0% WAITING> IDLE> IDLE
# [INFO]:    <- directory context /content/.buildozer/android/platform/python-for-android
# [DEBUG]:   All possible dists: [<Distribution: name myCalc with recipes (hostpython3, libffi, openssl, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, six, pyjnius, android, kivy, chardet, urllib3, requests, idna, certifi)>]
# [DEBUG]:   Dist matching name and arch: [<Distribution: name myCalc with recipes (hostpython3, libffi, openssl, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, six, pyjnius, android, kivy, chardet, urllib3, requests, idna, certifi)>]
# [DEBUG]:   Dist matching ndk_api and recipe: [<Distribution: name myCalc with recipes (hostpython3, libffi, openssl, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, six, pyjnius, android, kivy, chardet, urllib3, requests, idna, certifi)>]
# [INFO]:    Of the existing distributions, the following meet the given requirements:
# [INFO]:    	myCalc: min API 21, includes recipes (hostpython3, libffi, openssl, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, six, pyjnius, android, kivy, chardet, urllib3, requests, idna, certifi), built for archs (arm64-v8a, armeabi-v7a)
# [INFO]:    myCalc has compatible recipes, using this one
# [INFO]:    # Copying android package to current directory
# [INFO]:    # Android package filename not found in build output. Guessing...
# [INFO]:    # Found android package file: /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/dists/myCalc/build/outputs/apk/debug/myCalc-debug.apk
# [INFO]:    # Add version number to android package
# [INFO]:    # Android package renamed to myCalc-debug-1.apk
# [DEBUG]:   -> running cp /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/dists/myCalc/build/outputs/apk/debug/myCalc-debug.apk myCalc-debug-1.apk
# No setup.py/pyproject.toml used, copying full private data into .apk.
# Applying Java source code patches...
# Applying patch: src/patches/SDLActivity.java.patch
# # Copy /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/dists/myCalc/build/outputs/apk/debug/myCalc-debug.apk to /content/bin/myCalc-1-arm64-v8a_armeabi-v7a-debug.apk
# # Android packaging done!
# # APK myCalc-1-arm64-v8a_armeabi-v7a-debug.apk available in the bin directory
